# %% [markdown]
# <a href="https://colab.research.google.com/github/JSEFERINO/Curso_Estadistica/blob/main/00_Formato_para_trabajar_en_colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Formato para Trabajar en Colab Año: xxx**
# # **Escribe el Nombre del Curso**
# ## **Escribe tu nombre completo**
# > Email:
#
# > Celular:
#
# > Código Estudiantil

# %% [markdown]
# # **Librerias para Trabar en R**

# %%
# @title **Librerias para Trabar en R**
import rpy2.rinterface_lib.callbacks as rcb
import logging

# Desactivar warnings de R en Python
rcb.logger.setLevel(logging.ERROR)  # Solo muestra errores, no warnings
# %load_ext rpy2.ipython

# %% [markdown]
# <a name="inicio"></a>
#
#
# ## **1.** [Presentación](#T1)
# ## **2.** [Presentación2](#T2)
#
# ## **3.** [](#T3)
#
# ## **4.** [](#T4)
#
# ## **5.** [](#T5)
#
# ## **6.** [](#T6)
#
# ## **7.** [](#T7)
#
#
# ## **8.** [](#T8)
#
# ## **9.** [](#T9)
#
#
# ## **10.** [](#T10)
#
# ## **11.** [](#T11)
#
# ## **12.** [](#T12)
#
# ## **13.** [](#T13)
#
# ## **14.** [](#T14)
#
# ## **15.** [](#T15)
#
# ## **16.** [](#T16)
#
# ## **17.** [](#T17)
#
#
# ## **18.** [](#T18)
#
# ## **19.** [](#T19)
#
#
# ## **20.** [](#T20)
#
# ## **21.** [](#T21)
#
# ## **22.** [](#T22)
#
# ## **23.** [](#T23)
#
# ## **24.** [](#T24)
#
# ## **25.** [](#T25)
#
# ## **26.** [](#T26)
#
# ## **27.** [](#T27)
#
#
# ## **28.** [](#T28)
#
# ## **29.** [](#T29)
#
#
# ## **30.** [](#T30)
#
# ## **31.** [](#T31)

# %% [markdown]
# [ULTIMO](#ULTIMO)

# %% [markdown]
# [⬆️ Volver al inicio](#inicio)

# %% [markdown]
# <a name="T1"></a>
# ## **1. Presentación**

# %% [markdown]
# [⬆️ Volver al inicio](#inicio)

# %% [markdown]
# <a name="T2"></a>
# ## **2. **

# %% [markdown]
# [⬆️ Volver al inicio](#inicio)

# %% [markdown]
# <a name="T3"></a>
# ## **3. **

# %% [markdown]
# [⬆️ Volver al inicio](#inicio)

# %% [markdown]
# <a name="T4"></a>
# ## **4. **

# %% [markdown]
# [⬆️ Volver al inicio](#inicio)

# %% [markdown]
# <a name="T51"></a>
# ## **5. **

# %% [markdown]
# [⬆️ Volver al inicio](#inicio)

# %% [markdown]
# <a name="T6"></a>
# ## **6. **

# %% [markdown]
# [⬆️ Volver al inicio](#inicio)

# %% [markdown]
# <a name="T7"></a>
# ## **7. **

# %% [markdown]
# [⬆️ Volver al inicio](#inicio)

# %% [markdown]
# <a name="T7"></a>
# ## **7. **
#
# +

# %% [markdown]
# [⬆️ Volver al inicio](#inicio)

# %% [markdown]
# <a name="T8"></a>
# ## **8. **

# %% [markdown]
# [⬆️ Volver al inicio](#inicio)

# %% [markdown]
# <a name="T9"></a>
# ## **9. **

# %% [markdown]
# [⬆️ Volver al inicio](#inicio)

# %% [markdown]
# <a name="T10"></a>
# ## **10. **

# %% [markdown]
# [⬆️ Volver al inicio](#inicio)

# %% [markdown]
# <a name="T11"></a>
# ## **11. **

# %% [markdown]
# [⬆️ Volver al inicio](#inicio)

# %% [markdown]
# <a name="T12"></a>
# ## **12. **

# %% [markdown]
# [⬆️ Volver al inicio](#inicio)

# %% [markdown]
# <a name="T13"></a>
# ## **13. **

# %% [markdown]
# [⬆️ Volver al inicio](#inicio)

# %% [markdown]
# <a name="T14"></a>
# ## **14. **

# %% [markdown]
# [⬆️ Volver al inicio](#inicio)

# %% [markdown]
# <a name="T1"></a>
# ## **15. **

# %% [markdown]
# [⬆️ Volver al inicio](#inicio)

# %% [markdown]
# <a name="T16"></a>
# ## **16. **

# %% [markdown]
# [⬆️ Volver al inicio](#inicio)

# %% [markdown]
# <a name="T17"></a>
# ## **17. **

# %% [markdown]
# [⬆️ Volver al inicio](#inicio)

# %% [markdown]
# <a name="T18"></a>
# ## **18. **

# %% [markdown]
# [⬆️ Volver al inicio](#inicio)

# %% [markdown]
# <a name="T19"></a>
# ## **19. **

# %% [markdown]
# [⬆️ Volver al inicio](#inicio)

# %% [markdown]
# <a name="T20"></a>
# ## **20. **

# %% [markdown]
# [⬆️ Volver al inicio](#inicio)

# %% [markdown]
# <a name="T21"></a>
# ## **21. **

# %% [markdown]
# [⬆️ Volver al inicio](#inicio)

# %% [markdown]
# <a name="T22"></a>
# ## **22. **

# %% [markdown]
# [⬆️ Volver al inicio](#inicio)

# %% [markdown]
# <a name="T23"></a>
# ## **23. **

# %% [markdown]
# [⬆️ Volver al inicio](#inicio)

# %% [markdown]
# <a name="T24"></a>
# ## **24. **

# %% [markdown]
# [⬆️ Volver al inicio](#inicio)

# %% [markdown]
# <a name="T25"></a>
# ## **25. **

# %% [markdown]
# [⬆️ Volver al inicio](#inicio)

# %% [markdown]
# <a name="T26"></a>
# ## **26. **

# %% [markdown]
# [⬆️ Volver al inicio](#inicio)

# %% [markdown]
# <a name="T27"></a>
# ## **27. **

# %% [markdown]
# [⬆️ Volver al inicio](#inicio)

# %% [markdown]
# <a name="T28"></a>
# ## **28. **

# %% [markdown]
# [⬆️ Volver al inicio](#inicio)

# %% [markdown]
# <a name="T29"></a>
# ## **29. **

# %% [markdown]
# [⬆️ Volver al inicio](#inicio)

# %% [markdown]
# <a name="T30"></a>
# ## **30. **

# %% [markdown]
# [⬆️ Volver al inicio](#inicio)

# %% [markdown]
# ## **ULTIMO**
# [⬆️ Volver al ULTIMO](#ULTIMO)

# %% [markdown]
# <a name="ULTIMO"></a>

# %% [markdown]
# [⬆️ Volver al inicio](#inicio)
#
# ULTIMO
