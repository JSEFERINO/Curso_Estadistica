# %% [markdown]
# <a href="https://colab.research.google.com/github/JSEFERINO/Curso_Estadistica/blob/main/Estudiando_con_Samuel1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Tema 1. Diagrama de puntos** (o **dot plot**)
# ## **Concepto**
# + Un **diagrama de puntos** (o **dot plot**) es una representación gráfica de datos numéricos donde cada punto representa una observación individual.
# + Este tipo de gráfico es útil para visualizar la distribución de los datos de manera simple y efectiva, especialmente cuando el conjunto de datos no es muy grande.

# %%
# @title **1. Graficos de Puntos**
import matplotlib.pyplot as plt
import numpy as np

data = [161, 162, 163, 165, 165, 166, 166,
        161, 162, 163, 165, 165,
        160, 162, 163, 164, ]

# Crear un gráfico de puntos donde los repetidos se dibujen uno arriba del otro
plt.figure(figsize=(8, 2))

# Contar las ocurrencias de cada valor en los datos
unique_values, counts = np.unique(data, return_counts=True)

# Dibujar los puntos, apilando los repetidos verticalmente
for value, count in zip(unique_values, counts):
    plt.plot([value] * count, range(count), 'o', color='b')  # Apilar en el eje vertical
print(f'Consideremos el numero de puntos n = {len(data)}')
plt.yticks([])  # Ocultar eje y
plt.title("Diagrama de Puntos")
plt.xlabel("Estatura (cm)")
plt.show()
# Out:
# Consideremos el numero de puntos n = 16

# %%
# @title **2. Graficos de Puntos - Animacion**
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.animation as animation
from IPython.display import HTML


data = [161, 162, 163, 165, 165, 166, 166,
        161, 162, 163, 165, 165,
        160, 162, 163, 164, ]

# Crear la figura
fig, ax = plt.subplots(figsize=(8, 4))

# Función para inicializar el gráfico
def init():
    ax.clear()
    ax.set_title("Diagrama de Puntos")
    ax.set_xlabel("Estatura (cm)")
    ax.set_yticks([])

# Función para actualizar el gráfico en cada cuadro
def animate(i):
    ax.clear()
    ax.set_title("Diagrama de Puntos")
    ax.set_xlabel("Estatura (cm)")
    ax.set_yticks([])

    # Dibujar los puntos, apilando los repetidos verticalmente
    current_data = data[:i + 1]  # Agregar más datos a medida que avanza la animación
    unique_values, counts = np.unique(current_data, return_counts=True)
    for value, count in zip(unique_values, counts):
        ax.plot([value] * count, range(count), 'o', color='b')  # Apilar en el eje vertical

# Crear la animación
ani = animation.FuncAnimation(fig, animate, frames=len(data), init_func=init, interval=500, repeat=False)

# Mostrar la animación en Jupyter Notebook
HTML(ani.to_html5_video())
# Out:
# <video width="800" height="400" controls autoplay>
#   <source type="video/mp4" src="...">
#   Your browser does not support the video tag.
# </video>

# %%
# prompt: Hazme un ejemplo de un digrama de dispersion de Estatura y Peso

import matplotlib.pyplot as plt

# Datos de ejemplo (Estatura en cm, Peso en kg)
estatura = [155, 160, 165, 170, 175, 180, 185, 190 , 155, 147, 195]
peso = [50, 55, 60, 70, 75, 80, 85, 90, 86, 98, 100]

# Crear el diagrama de dispersión
plt.scatter(peso, estatura)

# Etiquetas de los ejes
plt.xlabel("Peso (kg) ")
plt.ylabel(" Estatura (cm)")

# Título del gráfico
plt.title("Diagrama de Dispersión: Estatura vs. Peso")

# Mostrar el gráfico
plt.show()

# %% [markdown]
# ### **Elementos clave del diagrama de puntos:**
# 1. **Puntos individuales**: Cada punto en el gráfico representa un valor de los datos. Si hay valores repetidos, los puntos se apilan verticalmente.
# 2. **Eje horizontal**: Representa los valores de la variable de interés. No siempre se usa un eje vertical, ya que la frecuencia se refleja en la acumulación de puntos.

# %% [markdown]
# ### **Cómo describir un diagrama de puntos:**
#
# 1. **Forma**:
#    - Describe la distribución general de los datos, observando si son **simétricos** o están **sesgados**.
#    - Puedes observar si los datos forman una curva uniforme, si tienden hacia un lado (sesgo), o si presentan varias acumulaciones (modos).
#    - Ejemplos:
#      - **Simétrica**: Los puntos se distribuyen de forma similar a ambos lados del centro.
#      - **Sesgo a la derecha**: Los datos tienden a concentrarse en valores bajos y hay una cola hacia los valores altos.
#      - **Sesgo a la izquierda**: Lo opuesto, con más datos concentrados en los valores altos.

# %%
# @title **3. Graficos de Puntos**
import matplotlib.pyplot as plt
import numpy as np

data = [161, 162, 163, 165, 162, 166, 164,
        161, 162, 163, 163, 163, 165, 164, 164,
        160, 162, 163, 164, 163]

# Crear un gráfico de puntos donde los repetidos se dibujen uno arriba del otro
plt.figure(figsize=(8, 2))

# Contar las ocurrencias de cada valor en los datos
unique_values, counts = np.unique(data, return_counts=True)

# Dibujar los puntos, apilando los repetidos verticalmente
for value, count in zip(unique_values, counts):
    plt.plot([value] * count, range(count), 'o', color='b')  # Apilar en el eje vertical
print(f'Consideremos el numero de puntos n = {len(data)}')
plt.yticks([])  # Ocultar eje y
plt.title("Diagrama de Puntos - Simetrico")
plt.xlabel("Estatura (cm)")
plt.show()
# Out:
# Consideremos el numero de puntos n = 20

# %%
# @title **4. Graficos de Puntos - Animacion  - Simetrico**
data = [161, 162, 163, 165, 162, 166, 164,
        161, 162, 163, 163, 163, 165, 164, 164,
        160, 162, 163, 164, 163]

# Crear la figura
fig, ax = plt.subplots(figsize=(10, 4))

# Función para inicializar el gráfico
def init():
    ax.clear()
    ax.set_title("Diagrama de Puntos")
    ax.set_xlabel("Estatura (cm)")
    ax.set_yticks([])

# Función para actualizar el gráfico en cada cuadro
def animate(i):
    ax.clear()
    ax.set_title("Diagrama de Puntos - Simetrico")
    ax.set_xlabel("Estatura (cm)")
    ax.set_yticks([])

    # Dibujar los puntos, apilando los repetidos verticalmente
    current_data = data[:i + 1]  # Agregar más datos a medida que avanza la animación
    unique_values, counts = np.unique(current_data, return_counts=True)
    for value, count in zip(unique_values, counts):
        ax.plot([value] * count, range(count), 'o', color='b')  # Apilar en el eje vertical

# Crear la animación
ani = animation.FuncAnimation(fig, animate, frames=len(data), init_func=init, interval=500, repeat=False)

# Mostrar la animación en Jupyter Notebook
HTML(ani.to_html5_video())
# Out:
# <video width="1000" height="400" controls autoplay>
#   <source type="video/mp4" src="...

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# @title **5. Diagrama de Puntos - Sesgado a la Izquierda**
import matplotlib.pyplot as plt
import numpy as np

data = [161, 162, 165, 165, 162, 166, 164, 167, 166, 167,
        163, 163, 165, 165, 167, 167, 164, 164, 168, 168, 169,
        160, 163, 166, 164, 167, 167, 166, 166, 166 ]

# Crear un gráfico de puntos donde los repetidos se dibujen uno arriba del otro
plt.figure(figsize=(8, 3))

# Contar las ocurrencias de cada valor en los datos
unique_values, counts = np.unique(data, return_counts=True)

# Dibujar los puntos, apilando los repetidos verticalmente
for value, count in zip(unique_values, counts):
    plt.plot([value] * count, range(count), 'o', color='b')  # Apilar en el eje vertical
print(f'Consideremos el numero de puntos n = {len(data)}')
plt.yticks([])  # Ocultar eje y
plt.title("Diagrama de Puntos - sesgado a la izquerda")
plt.xlabel("Estatura (cm)")
plt.show()
# Out:
# Consideremos el numero de puntos n = 30

# %%
# @title **6. Graficos de Puntos - Animacion  - sesgado a la izquerda**
data = [161, 162, 165, 165, 162, 166, 164, 167, 166, 167,
        163, 163, 165, 167, 165, 167, 164, 164, 168, 168, 169,
        160, 163, 166, 164, 167, 167, 166, 166, 166 ]

# Crear la figura
fig, ax = plt.subplots(figsize=(10, 4))

# Función para inicializar el gráfico
def init():
    ax.clear()
    ax.set_title("Diagrama de Puntos")
    ax.set_xlabel("Estatura (cm)")
    ax.set_yticks([])

# Función para actualizar el gráfico en cada cuadro
def animate(i):
    ax.clear()
    ax.set_title("Diagrama de Puntos - sesgado a la izquerda")
    ax.set_xlabel("Estatura (cm)")
    ax.set_yticks([])

    # Dibujar los puntos, apilando los repetidos verticalmente
    current_data = data[:i + 1]  # Agregar más datos a medida que avanza la animación
    unique_values, counts = np.unique(current_data, return_counts=True)
    for value, count in zip(unique_values, counts):
        ax.plot([value] * count, range(count), 'o', color='b')  # Apilar en el eje vertical

# Crear la animación
ani = animation.FuncAnimation(fig, animate, frames=len(data), init_func=init, interval=500, repeat=False)

# Mostrar la animación en Jupyter Notebook
HTML(ani.to_html5_video())
# Out:
# <video width="1000" height="400" controls autoplay>
#   <source type="video/mp4" src="...

# %%
# @title **7. Diagrama de Puntos - Sesgado a la Derecha**
import matplotlib.pyplot as plt
import numpy as np

data = [161, 162, 163, 160, 162, 166, 160,
        161, 162, 163, 161, 161, 165, 160, 164,
        160, 161, 161, 160, ]

# Crear un gráfico de puntos donde los repetidos se dibujen uno arriba del otro
plt.figure(figsize=(8, 3))

# Contar las ocurrencias de cada valor en los datos
unique_values, counts = np.unique(data, return_counts=True)

# Dibujar los puntos, apilando los repetidos verticalmente
for value, count in zip(unique_values, counts):
    plt.plot([value] * count, range(count), 'o', color='b')  # Apilar en el eje vertical
print(f'Consideremos el numero de puntos n = {len(data)}')
plt.yticks([])  # Ocultar eje y
plt.title("Diagrama de Puntos - Sesgado a la Derecha")
plt.xlabel("Estatura (cm)")
plt.show()
# Out:
# Consideremos el numero de puntos n = 19

# %%
# @title **8. Graficos de Puntos - Animacion  - Sesgado a la Derecha**
data = [161, 162, 163, 160, 162, 166, 160,
        161, 162, 163, 161, 161, 165, 160, 164,
        160, 161, 161, 160, ]
# Crear la figura
fig, ax = plt.subplots(figsize=(10, 4))

# Función para inicializar el gráfico
def init():
    ax.clear()
    ax.set_title("Diagrama de Puntos")
    ax.set_xlabel("Estatura (cm)")
    ax.set_yticks([])

# Función para actualizar el gráfico en cada cuadro
def animate(i):
    ax.clear()
    ax.set_title("Diagrama de Puntos - Sesgado a la Derecha")
    ax.set_xlabel("Estatura (cm)")
    ax.set_yticks([])

    # Dibujar los puntos, apilando los repetidos verticalmente
    current_data = data[:i + 1]  # Agregar más datos a medida que avanza la animación
    unique_values, counts = np.unique(current_data, return_counts=True)
    for value, count in zip(unique_values, counts):
        ax.plot([value] * count, range(count), 'o', color='b')  # Apilar en el eje vertical

# Crear la animación
ani = animation.FuncAnimation(fig, animate, frames=len(data), init_func=init, interval=500, repeat=False)

# Mostrar la animación en Jupyter Notebook
HTML(ani.to_html5_video())
# Out:
# <video width="1000" height="400" controls autoplay>
#   <source type="video/mp4" src="...

# %% [markdown]
# ### **Cómo describir un diagrama de puntos:**
#
#
# 2. **Fuerza**:
#    - Hace referencia a la densidad o concentración de los puntos en ciertas áreas. Si hay muchos puntos en una región, indica que hay una alta frecuencia de observaciones en esos valores.
#    - Un patrón claro, con muchos puntos apilados cerca de un valor, muestra una **alta concentración** o fuerza en esa región.

# %%
# Datos ficticios con repeticiones
data = [161, 162, 163, 170, 168, 166, 167, 167, 168, 168, 169, 169, 163, 169, 169, 164,164,
        161, 171, 170, 170, 168, 166, 167, 167, 168, 169, 168, 170, 165,
        160, 171, 170, 169, 168, 166, 167, 167, 168, 169,  170, 171]

# Crear un gráfico de puntos donde los repetidos se dibujen uno arriba del otro
plt.figure(figsize=(8, 4))

# Contar las ocurrencias de cada valor en los datos
unique_values, counts = np.unique(data, return_counts=True)

# Dibujar los puntos, apilando los repetidos verticalmente
for value, count in zip(unique_values, counts):
    plt.plot([value] * count, range(count), 'o', color='b')  # Apilar en el eje vertical

plt.yticks([])  # Ocultar eje y
plt.title("Diagrama de Puntos - Fuerza")
plt.xlabel("Estatura (cm)")
plt.show()

# %%
# @title **d. Graficos de Puntos - Animacion  - Sesgado a la Derecha**
data = [161, 162, 163, 170, 168, 166, 167, 167, 168, 168, 169, 169, 163, 169, 169, 164,164,
        161, 171, 170, 170, 168, 166, 167, 167, 168, 169, 168, 170, 165,
        160, 171, 170, 169, 168, 166, 167, 167, 168, 169,  170, 171]
# Crear la figura
fig, ax = plt.subplots(figsize=(10, 4))

# Función para inicializar el gráfico
def init():
    ax.clear()
    ax.set_title("Diagrama de Puntos")
    ax.set_xlabel("Estatura (cm)")
    ax.set_yticks([])

# Función para actualizar el gráfico en cada cuadro
def animate(i):
    ax.clear()
    ax.set_title("Diagrama de Puntos - Fuerza")
    ax.set_xlabel("Estatura (cm)")
    ax.set_yticks([])

    # Dibujar los puntos, apilando los repetidos verticalmente
    current_data = data[:i + 1]  # Agregar más datos a medida que avanza la animación
    unique_values, counts = np.unique(current_data, return_counts=True)
    for value, count in zip(unique_values, counts):
        ax.plot([value] * count, range(count), 'o', color='b')  # Apilar en el eje vertical

# Crear la animación
ani = animation.FuncAnimation(fig, animate, frames=len(data), init_func=init, interval=500, repeat=False)

# Mostrar la animación en Jupyter Notebook
HTML(ani.to_html5_video())
# Out:
# <video width="1000" height="400" controls autoplay>
#   <source type="video/mp4" src="...

# %% [markdown]
# ### **Cómo describir un diagrama de puntos:**
#
#
# 3. **Variabilidad**:
#    - La variabilidad se refiere a qué tan dispersos o concentrados están los datos. Si los puntos están muy juntos, hay **poca variabilidad**. Si están muy dispersos a lo largo del eje, hay **mucha variabilidad**.
#    - Esto se puede observar fácilmente viendo el rango de valores que cubren los puntos en el gráfico.

# %%
# @title **Diagrama de Puntos - mucha variabilidad**
data = [161, 152, 153, 175, 163, 162, 169, 164,164,
        151, 181,  179, 168, 172, 165,
        170, 181, 170, 169, 158, 171]

# Crear un gráfico de puntos donde los repetidos se dibujen uno arriba del otro
plt.figure(figsize=(10, 4))

# Contar las ocurrencias de cada valor en los datos
unique_values, counts = np.unique(data, return_counts=True)

# Dibujar los puntos, apilando los repetidos verticalmente
for value, count in zip(unique_values, counts):
    plt.plot([value] * count, range(count), 'o', color='b')  # Apilar en el eje vertical

plt.yticks([])  # Ocultar eje y
plt.title("Diagrama de Puntos - mucha variabilidad")
plt.xlabel("Estatura (cm)")
plt.show()

# %% [markdown]
# ### **Ejemplo de interpretación:**
# + Imagina un diagrama de puntos de la estatura de estudiantes. Si ves que la mayoría de los puntos están alrededor de 170 cm, con algunos datos dispersos hacia valores más bajos o más altos, podrías decir:
# - **Forma**: La distribución parece simétrica, ya que los puntos se agrupan de manera similar a ambos lados de los 170 cm.
# - **Fuerza**: La mayor concentración está en el rango de 165 a 175 cm, lo que sugiere que la mayoría de los estudiantes tienen estaturas cercanas a esos valores.
# - **Variabilidad**: Si los puntos están dispersos entre 150 cm y 190 cm, esto indica que hay una variabilidad moderada en las estaturas.

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.animation as animation
from IPython.display import HTML

# Datos con alta variabilidad
data = [161, 152, 153, 175, 168, 146, 167, 160, 163, 168, 169, 162, 163, 162, 169, 164,164,
        151, 181, 170, 174, 158, 136, 197, 161, 163, 179, 168, 172, 165,
        170, 181, 170, 169, 158, 126, 197, 161, 163, 189,  170, 171]

# Crear la figura
fig, ax = plt.subplots(figsize=(10, 4))

# Función para inicializar el gráfico
def init():
    ax.clear()
    ax.set_title("Diagrama de Puntos - Mucha Variabilidad")
    ax.set_xlabel("Estatura (cm)")
    ax.set_yticks([])

# Función para actualizar el gráfico en cada cuadro
def animate(i):
    ax.clear()
    ax.set_title("Diagrama de Puntos - Mucha Variabilidad")
    ax.set_xlabel("Estatura (cm)")
    ax.set_yticks([])

    # Dibujar los puntos, apilando los repetidos verticalmente
    current_data = data[:i+1]  # Agregar más datos a medida que avanza la animación
    unique_values, counts = np.unique(current_data, return_counts=True)
    for value, count in zip(unique_values, counts):
        ax.plot([value] * count, range(count), 'o', color='b')  # Apilar en el eje vertical

# Crear la animación
ani = animation.FuncAnimation(fig, animate, frames=len(data), init_func=init, interval=300, repeat=False)

# Mostrar la animación en Jupyter Notebook
HTML(ani.to_html5_video())
# Out:
# <video width="1000" height="400" controls autoplay>
#   <source type="video/mp4" src="...

# %%
# prompt: hazme boxplot a la data

import matplotlib.pyplot as plt

# Datos con alta variabilidad
data = [161, 152, 153, 175, 168, 146, 167, 160, 163, 168, 169, 162, 163, 162, 169, 164, 164,
        151, 181, 170, 174, 158, 136, 197, 161, 163, 179, 168, 172, 165,
        170, 181, 170, 169, 158, 126, 197, 161, 163, 189, 170, 171]

plt.figure(figsize=(8, 6))
plt.boxplot(data)
plt.title('Boxplot de la data')
plt.ylabel('Valores')
plt.show()

# %%
# Datos con alta variabilidad
data = [161, 152, 153, 175, 168, 146, 167, 160, 163, 168, 169, 162, 163, 162, 169, 164, 164,
        151, 181, 170, 174, 158, 136, 197, 161, 163, 179, 168, 172, 165,
        170, 181, 170, 169, 158, 126, 197, 161, 163, 189, 170, 171]

# Crear la figura
fig, ax = plt.subplots(figsize=(20, 4))

# Función para inicializar el gráfico
def init():
    ax.clear()
    ax.set_title("Diagrama de Puntos - Mucha Variabilidad")
    ax.set_xlabel("Estatura (cm)")
    ax.set_yticks([])

# Función para actualizar el gráfico en cada cuadro
def animate(i):
    ax.clear()
    ax.set_title("Diagrama de Puntos - Mucha Variabilidad")
    ax.set_xlabel("Estatura (cm)")
    ax.set_yticks([])

    # Dibujar los puntos, apilando los repetidos verticalmente
    current_data = data[:i + 1]  # Agregar más datos a medida que avanza la animación
    unique_values, counts = np.unique(current_data, return_counts=True)
    for value, count in zip(unique_values, counts):
        ax.plot([value] * count, range(count), 'o', color='b')  # Apilar en el eje vertical

# Crear la animación
ani = animation.FuncAnimation(fig, animate, frames=len(data), init_func=init, interval=100, repeat=False)

# Mostrar la animación en Jupyter Notebook
HTML(ani.to_html5_video())
# Out:
# <video width="2000" height="400" controls autoplay>
#   <source type="video/mp4" src="...

# %%
# @title **Diagrama da caja y Bigotes para EDAD**
from matplotlib import pyplot as plt
import seaborn as sns
sns.boxplot(x=data, color='orange')
plt.title('Diagrama de caja para la variable EDAD')
plt.show()

# %%
  q1 = np.percentile(data, 25)
  q2 = np.percentile(data, 50)
  q3 = np.percentile(data, 75)
  RIQ = q3 - q1


  print(f'Q1 = {q1}')
  print(f'Q2 = {q2}')
  q1 = np.percentile(data, 25)
  q2 = np.percentile(data, 50)
  q3 = np.percentile(data, 75)
  RIQ = q3 - q1


  print(f'Q1 = {q1}')
  print(f'Q2 = {q2}')
  print(f'Q3 = {q3}')
  print(f'Rango intercuartil RIQ= {q3-q1}')

  Bigote_2 = q3 + 1.5 * RIQ
  Bigote_1 = q1 - 1.5 * RIQ

  print(f'Bigote_2 = {Bigote_2}')
  print(f'Bigote_1 = {Bigote_1}')
# Out:
# Q1 = 161.0
# Q2 = 166.0
# Q1 = 161.0
# Q2 = 166.0
# Q3 = 170.0
# Rango intercuartil RIQ= 9.0
# Bigote_2 = 183.5
# Bigote_1 = 147.5
